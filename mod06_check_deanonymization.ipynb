# %%
import pandas as pd
from mod06_deanonymize import load_data, link_records, deanonymization_rate

# %%
anon_path = "mod06_data/anonymized.csv"
aux_path = "mod06_data/auxiliary.csv"

# %% [markdown]
# ### Load and review the data

# %%
anon, aux = load_data(anon_path, aux_path)

# %%
anon.head(20)

# %% [markdown]
# ### Merge the datasets by age, gender, and zip3 and return the unique matches

# %%
matches = link_records(anon, aux)
matches.head()

# %% [markdown]
# ### Calculate the match rate

# %%
rate = deanonymization_rate(matches, anon)
print(rate)

# %% [markdown]
# # Discussion Questions

# %% [markdown]
# ### Describe your reaction to the match rate. What sources of data might be prone to privacy issues?

# %% [markdown]
# The match rate was a little lower than I expected. I figured age, zip code, and gender would be enough to deanonymize majority of the people. Medical and finacial records are the two sources of data that would probaly be the most prone to privacy issues. Location tracking such as gps or apps like life360 could be an issue since it could reveal address information. Any other data that includes a persons social secuirty number, address, birthday, etc can be prone to privacy issues.

# %% [markdown]
# ### Provide examples of at least two other variables that could increase the match rate if included.

# %% [markdown]
# Other variables that could increase the match rate are ethnicity, eye color, hair color, job title, employer, etc.
